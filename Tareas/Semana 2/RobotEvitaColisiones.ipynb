# %%
import random
import time
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from IPython.display import display

# ==========================================
# 1. PARÁMETROS DEL ENTORNO
# ==========================================
n, m = 12, 12
K = 4
ciclos = 80
prob_arrebato = 0.10  # 10% de probabilidad de cambiar de dirección repentinamente

# Retículo principal y Matriz de Memoria (Rastro térmico)
reticulo = [[0 for _ in range(m)] for _ in range(n)]
memoria = [[0 for _ in range(m)] for _ in range(n)]

# Colocar los 4 objetos aleatorios
obs_colocados = 0
while obs_colocados < K:
    r, c = random.randint(0, n-1), random.randint(0, m-1)
    if reticulo[r][c] == 0:
        reticulo[r][c] = 1
        obs_colocados += 1

# Colocar robot
robot_r, robot_c = random.randint(0, n-1), random.randint(0, m-1)
while reticulo[robot_r][robot_c] != 0:
    robot_r, robot_c = random.randint(0, n-1), random.randint(0, m-1)
reticulo[robot_r][robot_c] = 2

dir_actual = random.randint(0, 3)

# Sensores relativos: Frente-Izq, Frente-Centro, Frente-Der, Detrás
sensores_relativos = {
    0: [(-1, -1), (-1, 0), (-1, 1), (1, 0)], # Norte
    1: [(-1, 1),  (0, 1),  (1, 1),  (0, -1)], # Este
    2: [(1, 1),   (1, 0),  (1, -1), (-1, 0)], # Sur
    3: [(1, -1),  (0, -1), (-1, -1), (0, 1)]  # Oeste
}

# ==========================================
# 2. RENDERIZADO VISUAL CONTINUO
# ==========================================
fig, ax = plt.subplots(figsize=(7, 7))
plt.close(fig)
dh = display(fig, display_id=True)

def visualizar_estado(matriz, r_rob, c_rob, direccion, estado_txt):
    ax.clear()

    # Dibujar mapa, objetos y memoria
    for i in range(n):
        for j in range(m):
            if matriz[i][j] == 1:
                ax.add_patch(patches.Rectangle((j-0.5, i-0.5), 1, 1, color='#2c3e50'))
            elif matriz[i][j] == 0:
                intensidad = memoria[i][j]
                if intensidad > 0:
                    alpha_val = min(0.8, intensidad / 20.0)
                    ax.add_patch(patches.Rectangle((j-0.5, i-0.5), 1, 1, color='#3498db', alpha=alpha_val))
                    ax.add_patch(patches.Rectangle((j-0.5, i-0.5), 1, 1, fill=False, ec='#ecf0f1', lw=0.5))
                else:
                    ax.add_patch(patches.Rectangle((j-0.5, i-0.5), 1, 1, color='white', ec='#ecf0f1', lw=0.5))

    # Sombrear el alcance de los sensores
    offsets_sensores = sensores_relativos[direccion]
    for dr, dc in offsets_sensores:
        sr, sc = r_rob + dr, c_rob + dc
        if 0 <= sr < n and 0 <= sc < m:
            ax.add_patch(patches.Rectangle((sc-0.5, sr-0.5), 1, 1, color='#f1c40f', alpha=0.35))

    # Robot
    ax.add_patch(patches.Circle((c_rob, r_rob), 0.3, color='#e74c3c', zorder=5))
    frente_dr, frente_dc = offsets_sensores[1]
    ax.add_patch(patches.Circle((c_rob + frente_dc*0.2, r_rob + frente_dr*0.2), 0.08, color='black', zorder=6))

    ax.set_xlim(-0.5, m-0.5)
    ax.set_ylim(n-0.5, -0.5)
    ax.set_aspect('equal')
    ax.axis('off')

    color_titulo = "#8e44ad" if "Repentino" in estado_txt else "black" if estado_txt == "Explorando" else "red"
    ax.set_title(f"Simulación de Autómata (Sensores y Memoria)\nEstado: {estado_txt}",
                 fontsize=12, pad=10, color=color_titulo, fontweight='bold')
    dh.update(fig)

# ==========================================
# 3. DINÁMICA CON ARREBATOS ORGÁNICOS
# ==========================================
for ciclo in range(ciclos):
    # Enfriar el rastro de memoria
    for i in range(n):
        for j in range(m):
            if memoria[i][j] > 0:
                memoria[i][j] -= 1

    estado_actual = "Explorando"
    offsets = sensores_relativos[dir_actual]
    lecturas = []

    # Lectura pura de sensores (sin ruido)
    for dr, dc in offsets:
        sr, sc = robot_r + dr, robot_c + dc
        if sr < 0 or sr >= n or sc < 0 or sc >= m or reticulo[sr][sc] == 1:
            lecturas.append(True) # Bloqueado
        else:
            lecturas.append(False) # Libre

    frente_izq_bloqueado, frente_bloqueado, frente_der_bloqueado, detras_bloqueado = lecturas

    visualizar_estado(reticulo, robot_r, robot_c, dir_actual, estado_actual)
    time.sleep(0.2)

    # El robot siente el impulso de cambiar de dirección
    quiere_cambiar = random.random() < prob_arrebato

    if quiere_cambiar and not frente_bloqueado:
        # Intenta ceder al arrebato verificando si los lados están libres
        opciones_laterales = []
        if not frente_izq_bloqueado: opciones_laterales.append((dir_actual - 1) % 4)
        if not frente_der_bloqueado: opciones_laterales.append((dir_actual + 1) % 4)

        if opciones_laterales:
            dir_actual = random.choice(opciones_laterales)
            estado_actual = "¡Giro Repentino!"
        else:
            # Si quiere girar pero está encapsulado a los lados, simplemente sigue derecho
            memoria[robot_r][robot_c] = 20
            reticulo[robot_r][robot_c] = 0
            robot_r += offsets[1][0]
            robot_c += offsets[1][1]
            reticulo[robot_r][robot_c] = 2

    elif not frente_bloqueado:
        # Comportamiento normal: avanzar
        memoria[robot_r][robot_c] = 20
        reticulo[robot_r][robot_c] = 0
        robot_r += offsets[1][0]
        robot_c += offsets[1][1]
        reticulo[robot_r][robot_c] = 2

    else:
        # Comportamiento normal: esquivar el obstáculo
        estado_actual = "Evadiendo Obstáculo"
        opciones_giro = []
        if not frente_izq_bloqueado: opciones_giro.append((dir_actual - 1) % 4)
        if not frente_der_bloqueado: opciones_giro.append((dir_actual + 1) % 4)

        if len(opciones_giro) == 2:
            # Evalúa el rastro de memoria para decidir el mejor camino
            r1, c1 = robot_r + sensores_relativos[opciones_giro[0]][1][0], robot_c + sensores_relativos[opciones_giro[0]][1][1]
            r2, c2 = robot_r + sensores_relativos[opciones_giro[1]][1][0], robot_c + sensores_relativos[opciones_giro[1]][1][1]

            rastro1 = memoria[r1][c1] if (0<=r1<n and 0<=c1<m) else 99
            rastro2 = memoria[r2][c2] if (0<=r2<n and 0<=c2<m) else 99

            if rastro1 < rastro2: dir_actual = opciones_giro[0]
            elif rastro2 < rastro1: dir_actual = opciones_giro[1]
            else: dir_actual = random.choice(opciones_giro)

        elif len(opciones_giro) == 1:
            dir_actual = opciones_giro[0]
        elif not detras_bloqueado:
            dir_actual = (dir_actual + 2) % 4

    # Renderizar el resultado del movimiento
    if estado_actual != "Explorando":
        visualizar_estado(reticulo, robot_r, robot_c, dir_actual, estado_actual)
        time.sleep(0.15) # Pausa extra para notar el giro

print("Simulación finalizada.")
